# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51531/E-AI-Lab/blob/main/E_XI_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dice-ml
# !pip install xgboost
# !pip install shap
